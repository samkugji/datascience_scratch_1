# %% [markdown]
# # 데이터 시각화
#
# - 데이터 시각화의 목적
#     - 데이터 탐색
#     - 데이터 전달
#
# - 주로 사용되는 차트
#     - 라인 플롯(line plot)
#     - 스캐터 플롯(scatter plot)
#     - 컨투어 플롯(contour plot)
#     - 서피스 플롯(surface plot)
#     - 바 차트(bar chart)
#     - 히스토그램(histogram)
#     - 박스 플롯(box plot)
#
# - 위 차트들만 잘 사용해도 대부분의 통계분석은 커버가 가능하다.

# %% [markdown]
# ## 1. matplotlib

# %% [markdown]
# - http://matplotlib.org/gallery.html
# - matplotlib의 서브패키지인 pyplot 사용

# %%
# 맥의 경우에는 한글 폰트명이 깨지는 문제가 발생하기 때문에 폰트를 따로 지정해주어야 된다.

import matplotlib
matplotlib.rc('font',family='AppleGothic')

# %%
# 항상 matplotlib의 서브 패키지인 pyplot을 불러온다.

from matplotlib import pyplot as plt ## 관습적으로 alias를 plt로 사용한다.

# %% [markdown]
# - x 축에 연도, y축에는 GDP가 있는 선 그래프를 만들자.

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
plt.plot(years,               # x 값
         gdp,                 # y 값
         color = 'green',     # 선 색깔
         marker = 'o',        # 데이터 포인트 스타일
         linestyle = 'solid') # 선 스타일

# %%
# 제목
plt.title('명목GDP')

# %%
# y축 레이블
plt.ylabel('Bilions of $')

# %%
# plotting
plt.show()

# %%
## 모든 과정을 하나의 셀에다가 적어주어도  된다.
plt.plot(years, gdp, color = 'green', marker = 'o', linestyle = 'solid')
plt.title('명목GDP')
plt.ylabel('Bilions of $')
plt.show()

# %% [markdown]
# ## 2. 막대 그래프

# %% [markdown]
# - 주로 이산적인 항목들의 변화를 보여줄 때 사용한다.
# - x와 y에는 문자열이 올수 없기 때문에 어떤 집단의 빈도수 같은 경우에는 집단의 x 좌표를 임의로 설정해주고, x값에 레이블을 다시 달아주어야된다.

# %% [markdown]
# - 아카데미 시상식에서 받은 상의 개수를 나타내어 보자

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

# %%
## x값 위치에 문자열을 그대로 입력해주면 에러가 난다.
plt.bar(movies, num_oscars)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-b065ca93158d> in <module>()
#       1 ## x값 위치에 문자열을 그대로 입력해주면 에러가 난다.
# ----> 2 plt.bar(movies, num_oscars)
#
# /Users/sechang/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2702     try:
#    2703         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2704                      **kwargs)
#    2705     finally:
#    2706         ax._hold = washold
#
# /Users/sechang/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /Users/sechang/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2103         if align == 'center':
#    2104             if orientation == 'vertical':
# -> 2105                 left = [left[i] - width[i] / 2. for i in xrange(len(left))]
#    2106             elif orientation == 'horizontal':
#    2107                 bottom = [bottom[i] - height[i] / 2.
#
# /Users/sechang/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in <listcomp>(.0)
#    2103         if align == 'center':
#    2104             if orientation == 'vertical':
# -> 2105                 left = [left[i] - width[i] / 2. for i in xrange(len(left))]
#    2106             elif orientation == 'horizontal':
#    2107                 bottom = [bottom[i] - height[i] / 2.
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %%
# 막대너비의 기본값은 0.8이므로, 막대가 가운데로 올 수 있도록 왼쪽 좌표에 0.1씩 더해주자
xs = [i + 0.1 for i, _ in enumerate(movies)]
# xs = [0.1, 1.1, 2.1, 3.1, 4.1], 일반적은로 _ 변수는 쓰지 않는 변수를 할당할 때 사용함

# %%
# plot bars with left x-coordinates [xs], heights [num_oscars]
plt.bar(xs, num_oscars)
plt.ylabel("# of Academy Awards")
plt.title("My Favorite Movies")

plt.show()

# %%
# 막대의 가운데에 영화 제품 레이블이 오게 만들자.

plt.bar(xs, num_oscars)
plt.ylabel("# of Academy Awards")
plt.title("My Favorite Movies")
plt.xticks([i + 0.1 for i, _ in enumerate(movies)], movies)
plt.show()

# %%
## seaborn이라는 패키지를 사용하면 더 쉽게 표현할 수 있다.
## seaborn 예제

import seaborn as sns
sns.barplot(movies, num_oscars)
plt.show()

# %%
from collections import Counter

grades = [83,95,91,87,70,0,85,82,100,67,73,77,0]
decile = lambda grade: grade // 10 * 10

histogram = Counter(decile(grade) for grade in grades)
# Counter([grade // 10 * 10 for grade in grades])
# Counter({80: 4, 70: 3, 0: 2, 90: 2, 100: 1, 60: 1})

plt.bar([x - 4 for x in histogram.keys()], # shift each bar to the left by 4
        histogram.values(),                # give each bar its correct height
        8)                                 # give each bar a width of 8
plt.axis([-5, 105, 0, 5])                  # x-axis from -5 to 105,
                                           # y-axis from 0 to 5
plt.xticks([10 * i for i in range(11)])    # x-axis labels at 0, 10, ..., 100
plt.xlabel("Decile")
plt.ylabel("# of Students")
plt.title("Distribution of Exam 1 Grades")
plt.show()

# %% [markdown]
# > https://python-graph-gallery.com/
